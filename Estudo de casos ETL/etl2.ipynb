# %%
import pandas as pd

# %%
file_path="datasets/infracoes_2024.csv"

# %%
df = pd.read_csv(file_path, delimiter=';')

# %%
df.head(10)
# Out:
#        datainfracao horainfracao   dataimplantacao  \
# 0  01/01/2024 00:00     00:59:00  03/01/2024 00:00
# 1  01/01/2024 00:00     01:08:00  03/01/2024 00:00
# 2  01/01/2024 00:00     01:50:00  03/01/2024 00:00
# 3  01/01/2024 00:00     02:00:00  03/01/2024 00:00
# 4  01/01/2024 00:00     02:18:00  03/01/2024 00:00
# 5  01/01/2024 00:00     02:40:00  03/01/2024 00:00
# 6  01/01/2024 00:00     02:40:00  03/01/2024 00:00
# 7  01/01/2024 00:00     03:04:00  03/01/2024 00:00
# 8  01/01/2024 00:00     03:06:00  03/01/2024 00:00
# 9  01/01/2024 00:00     03:06:00  03/01/2024 00:00
#
#                       agenteequipamento  infracao  \
# 0  Código 8 - AUTOS NO TALÃO ELETRÔNICO      5479
# 1  Código 8 - AUTOS NO TALÃO ELETRÔNICO      6564
# 2  Código 8 - AUTOS NO TALÃO ELETRÔNICO      5452
# 3  Código 8 - AUTOS NO TALÃO ELETRÔNICO      5452
# 4  Código 8 - AUTOS NO TALÃO ELETRÔNICO      6050
# 5  Código 8 - AUTOS NO TALÃO ELETRÔNICO      5452
# ...

# %%
import os

print("Caminho absoluto:", os.path.abspath(file_path))
print("Arquivo existe?", os.path.exists(file_path))
# Out:
# Caminho absoluto: c:\Users\zovka\OneDrive\Desktop\integraçao\Projeto-de-integra-o-de-dados\Estudo de casos ETL\datasets\infracoes_2024.csv
# Arquivo existe? True
