# %% [markdown]
# ## Instalando as bibliotecas necessárias
# Realizamos a instalação de todas as bibliotecas que serão utilizadas ao longo do projeto.

# %%
# Instalação de pacotes
print("Instalando as bibliotecas necessárias...")
# !pip install sqlalchemy psycopg2-binary pandas -q
print("Instalação concluída.")
# Out:
# Instalando as bibliotecas necessárias...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 26.1 MB/s eta 0:00:00
# Instalação concluída.

# %% [markdown]
# ## Extração dos dados (Extract)
# Fazemos a leitura dos arquivos CSV contendo os dados de infrações de trânsito dos anos de 2023, 2024 e 2025, carregando-os em dataframes do Pandas.

# %%
# Extração dos dados (Extract)
import pandas as pd

arquivos = ['infracoes_2023.csv', 'infracoes_2024.csv', 'infracoes_2025.csv']
df_bruto = []

for nome_do_arquivo_csv in arquivos:
  print(f"Lendo o arquivo '{nome_do_arquivo_csv}'...")

  try:
      df_bruto.append(pd.read_csv(nome_do_arquivo_csv, sep=';', encoding='UTF-8'))
      print("Arquivo lido com sucesso! Veja uma amostra dos dados:")
      display(df_bruto[-1].head()) # .head() mostra as 5 primeiras linhas
  except FileNotFoundError:
      print(f"ERRO: Arquivo '{nome_do_arquivo_csv}' não encontrado. Verifique se o nome está correto e se o upload foi concluído.")
  except Exception as e:
      print(f"Ocorreu um erro ao ler o arquivo: {e}")
# Out:
# Lendo o arquivo 'infracoes_2023.csv'...
# Arquivo lido com sucesso! Veja uma amostra dos dados:
#   datainfracao horainfracao dataimplantacao  \
# 0   2023-01-01     00:01:00      2023-01-06
# 1   2023-01-01     00:27:00      2023-01-06
# 2   2023-01-01     00:27:00      2023-01-06
# 3   2023-01-01     00:52:00      2023-01-06
# 4   2023-01-01     00:52:00      2023-01-06
#
#                        agenteequipamento  infracao  \
# 0  Código 8 - AUTOS NO TALÃO ELETRÔNICO       7234
# 1  Código 8 - AUTOS NO TALÃO ELETRÔNICO       5835
# 2  Código 8 - AUTOS NO TALÃO ELETRÔNICO       5215
# 3  Código 8 - AUTOS NO TALÃO ELETRÔNICO       5550
# 4  Código 8 - AUTOS NO TALÃO ELETRÔNICO       5550
#
#                                    descricaoinfracao  \
# 0  Quando o veículo estiver em movimento deixar d...
# 1  Desobedecer às ordens emanadas da autoridade c...
# 2  Dirigir ameaçando os pedestres que estejam atr...
# 3  Estacionar o veículo em locais e horários proi...
# 4  Estacionar o veículo em locais e horários proi...
#
#                         amparolegal  \
# 0  Art. 250, Inc. I, alínea a
# 1  Art. 195
# 2  Art. 170
# 3  Art. 181, Inc. XVIII
# 4  Art. 181, Inc. XVIII
#
#                                     localcometimento
# 0  RUA RIBEIRO DE BRITO, SOB O SEMAFORO N. 155   ...
# 1  RUA DOS NAVEGANTES, CRUZAMENTO COM A RUA PADRE...
# 2  RUA DOS NAVEGANTES, CRUZAMENTO COM A RUA PADRE...
# 3  AVENIDA ENGENHEIRO DOMINGOS FERREIRA, EM FRENT...
# 4  AVENIDA ENGENHEIRO DOMINGOS FERREIRA, EM FRENT...
# Lendo o arquivo 'infracoes_2024.csv'...
# Arquivo lido com sucesso! Veja uma amostra dos dados:
#        datainfracao horainfracao   dataimplantacao  \
# 0  01/01/2024 00:00     00:59:00  03/01/2024 00:00
# 1  01/01/2024 00:00     01:08:00  03/01/2024 00:00
# 2  01/01/2024 00:00     01:50:00  03/01/2024 00:00
# 3  01/01/2024 00:00     02:00:00  03/01/2024 00:00
# 4  01/01/2024 00:00     02:18:00  03/01/2024 00:00
#
#                       agenteequipamento  infracao  \
# 0  Código 8 - AUTOS NO TALÃO ELETRÔNICO      5479
# 1  Código 8 - AUTOS NO TALÃO ELETRÔNICO      6564
# 2  Código 8 - AUTOS NO TALÃO ELETRÔNICO      5452
# 3  Código 8 - AUTOS NO TALÃO ELETRÔNICO      5452
# 4  Código 8 - AUTOS NO TALÃO ELETRÔNICO      6050
#
#                                    descricaoinfracao          amparolegal  \
# 0  Estacionar o veículo impedindo a movimentação ...     Art. 181, Inc. X
# 1  Conduzir o veículo transportando passageiros e...    Art. 230, Inc. II
# 2                   Estacionar o veículo no passeio.  Art. 181, Inc. VIII
# 3                   Estacionar o veículo no passeio.  Art. 181, Inc. VIII
# 4  Avançar o sinal vermelho do semáforo, exceto o...             Art. 208
#
#                                     localcometimento
# 0          AVENIDA BOA VIAGEM, LADO OPOSTO AO N. 618
# 1  AVENIDA BOA VIAGEM, EM FRENTE AO N. 500. SENTI...
# 2  RUA CAPITAO REBELINHO, EM FRENTE AO N. 482, SE...
# 3         RUA CAPITAO REBELINHO, EM FRENTE AO N. 482
# 4  AVENIDA CONSELHEIRO AGUIAR, SOB AO SEMAFORO N....
# Lendo o arquivo 'infracoes_2025.csv'...
# Arquivo lido com sucesso! Veja uma amostra dos dados:
# /tmp/ipython-input-2274849484.py:11: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_bruto.append(pd.read_csv(nome_do_arquivo_csv, sep=';', encoding='UTF-8'))
#   datainfracao horainfracao dataimplantacao  \
# 0   2025-01-01     00:01:00      2025-01-09
# 1   2025-01-01     00:03:00      2025-01-09
# 2   2025-01-01     00:05:00      2025-01-09
# 3   2025-01-01     00:05:00      2025-01-09
# 4   2025-01-01     00:05:00      2025-01-09
#
#                       agenteequipamento  infracao  \
# 0  Código 8 - AUTOS NO TALÃO ELETRÔNICO      7340
# 1  Código 8 - AUTOS NO TALÃO ELETRÔNICO      7684
# 2  Código 8 - AUTOS NO TALÃO ELETRÔNICO      5487
# 3  Código 8 - AUTOS NO TALÃO ELETRÔNICO      5487
# 4  Código 8 - AUTOS NO TALÃO ELETRÔNICO      5487
#
#                                    descricaoinfracao        amparolegal  \
# 0  Dirigir o veículo usando calçado que não se fi...  Art. 252, Inc. IV
# 1  Conduzir motocicleta, motoneta ou ciclomotor c...        Art. 244, X
# 2  Estacionar o veículo ao lado de outro veículo ...  Art. 181, Inc. XI
# 3  Estacionar o veículo ao lado de outro veículo ...  Art. 181, Inc. XI
# 4  Estacionar o veículo ao lado de outro veículo ...  Art. 181, Inc. XI
#
#                                 localcometimento
# 0  RUA ALCIDES CARNEIRO LEAL, EM FRENTE AO N. 71
# 1  RUA ALCIDES CARNEIRO LEAL, EM FRENTE AO N. 71
# 2     AVENIDA BOA VIAGEM, LADO OPOSTO AO N. 3232
# 3     AVENIDA BOA VIAGEM, LADO OPOSTO AO N. 3232
# 4         AVENIDA BOA VIAGEM, AO LADO AO N. 3232

# %% [markdown]
# ## Carga dos dados no Banco (Load)
# Com os dados extraídos, esta etapa realiza a carga  das informações em um banco de dados PostgreSQL. Os dados de cada ano são adicionados sequencialmente.

# %%
# Carga dos dados no Banco (Load)
from sqlalchemy import create_engine
from google.colab import userdata

db_user = 'postgres'
db_pass = userdata.get('db_password')
db_host = 'db.sclbdkhswhfmkrdejzve.supabase.co'
db_port = '6543'
db_name = 'postgres'

# String de conexão
connection_string = f"postgresql://postgres.sclbdkhswhfmkrdejzve:{db_pass}@aws-1-sa-east-1.pooler.supabase.com:6543/postgres"

try:
    engine = create_engine(connection_string)
    print("Conexão com o PostgreSQL estabelecida com sucesso.")

    # Nome da tabela que será criada no banco
    nome_tabela_no_banco = 'infracoes_brutas'

    print(f"Iniciando a carga de dados para a tabela '{nome_tabela_no_banco}'...")

    # O comando to_sql envia os dados do DataFrame para o SQL
    # if_exists='replace' apaga a tabela se ela já existir e a cria novamente.
    # Use if_exists='append' se quiser adicionar os dados a uma tabela que já existe.

    df_bruto[0].to_sql(nome_tabela_no_banco, con=engine, if_exists='replace', index=False)
    for i in range(1, len(df_bruto)):
      df_bruto[i].to_sql(nome_tabela_no_banco, con=engine, if_exists='append', index=False)

    print("Carga de dados concluída!")

except Exception as e:
    print(f"Ocorreu um erro na conexão ou carga para o banco: {e}")
# Out:
# Conexão com o PostgreSQL estabelecida com sucesso.
# Iniciando a carga de dados para a tabela 'infracoes_brutas'...
# Carga de dados concluída!

# %% [markdown]
# ## Verificação da Carga no Banco de Dados
# Após a carga, é fundamental verificar se os dados foram inseridos corretamente. Esta seção executa uma consulta para confirmar que as informações estão no banco de dados.

# %%
#Verificação
print("Verificando se os dados foram salvos corretamente no banco...")

try:
    # Puxa as 5 primeiras linhas da tabela que você acabou de criar
    query = f"SELECT * FROM {nome_tabela_no_banco} LIMIT 5"
    df_do_banco = pd.read_sql(query, con=engine)

    print("SUCESSO! Os dados estão no PostgreSQL. Veja a amostra lida do banco:")
    display(df_do_banco)
except Exception as e:
    print(f"Ocorreu um erro ao tentar ler os dados do banco: {e}")
# Out:
# Verificando se os dados foram salvos corretamente no banco...
# SUCESSO! Os dados estão no PostgreSQL. Veja a amostra lida do banco:
#   datainfracao horainfracao dataimplantacao  \
# 0   2023-01-01     00:01:00      2023-01-06
# 1   2023-01-01     00:27:00      2023-01-06
# 2   2023-01-01     00:27:00      2023-01-06
# 3   2023-01-01     00:52:00      2023-01-06
# 4   2023-01-01     00:52:00      2023-01-06
#
#                        agenteequipamento  infracao  \
# 0  Código 8 - AUTOS NO TALÃO ELETRÔNICO       7234
# 1  Código 8 - AUTOS NO TALÃO ELETRÔNICO       5835
# 2  Código 8 - AUTOS NO TALÃO ELETRÔNICO       5215
# 3  Código 8 - AUTOS NO TALÃO ELETRÔNICO       5550
# 4  Código 8 - AUTOS NO TALÃO ELETRÔNICO       5550
#
#                                    descricaoinfracao  \
# 0  Quando o veículo estiver em movimento deixar d...
# 1  Desobedecer às ordens emanadas da autoridade c...
# 2  Dirigir ameaçando os pedestres que estejam atr...
# 3  Estacionar o veículo em locais e horários proi...
# 4  Estacionar o veículo em locais e horários proi...
#
#                         amparolegal  \
# 0  Art. 250, Inc. I, alínea a
# 1  Art. 195
# 2  Art. 170
# 3  Art. 181, Inc. XVIII
# 4  Art. 181, Inc. XVIII
#
#                                     localcometimento
# 0  RUA RIBEIRO DE BRITO, SOB O SEMAFORO N. 155   ...
# 1  RUA DOS NAVEGANTES, CRUZAMENTO COM A RUA PADRE...
# 2  RUA DOS NAVEGANTES, CRUZAMENTO COM A RUA PADRE...
# 3  AVENIDA ENGENHEIRO DOMINGOS FERREIRA, EM FRENT...
# 4  AVENIDA ENGENHEIRO DOMINGOS FERREIRA, EM FRENT...

# %% [markdown]
# ## Transformação dos Dados (Transform)
# Nesta etapa, os dados brutos carregados no banco de dados passam por um processo de transformação. O objetivo é limpar, padronizar e enriquecer as informações, preparando-as para análise.

# %% [markdown]
# ## Tratamento da Coluna datainfracao
# Ajustamos a coluna datainfracao, convertendo-a para o tipo DATE e renomeando-a para data_infracao.

# %%
from sqlalchemy import create_engine, text

# Recria a conexão com o banco (usando o Connection Pooler)
engine = create_engine(connection_string)

# Altera o nome da coluna "datainfracao" para "data_infracao", tira a hora e deixa somente a data (no formato DATE)
sql_commands =[
    text("""
    ALTER TABLE infracoes_brutas
    ADD COLUMN IF NOT EXISTS data_infracao DATE;
    """),
    text("""
    UPDATE infracoes_brutas
    SET data_infracao = CASE
    WHEN datainfracao LIKE '%/%' THEN CAST(TO_TIMESTAMP(datainfracao, 'DD/MM/YYYY HH24:MI') AS DATE)
    WHEN datainfracao LIKE '%-%' THEN TO_DATE(datainfracao, 'YYYY-MM-DD')
    ELSE NULL
    END;
    """),
    text("""
    ALTER TABLE infracoes_brutas
    DROP COLUMN datainfracao;
    """)
]

try:
    # Garantir que a conexão seja fechada corretamente
    with engine.connect() as connection:
        for command in sql_commands:
            connection.execute(command)
            connection.commit()
    print("Instruções executadas com sucesso!")

except Exception as e:
    print(f"Ocorreu um erro ao executar o comando: {e}")
# Out:
# Instruções executadas com sucesso!

# %% [markdown]
# ## Tratamento da coluna horainfracao
# Convertemos a coluna horainfracao para o tipo TIME e a renomeamos para hora_infracao.

# %%
from sqlalchemy import create_engine, text

# Recria a conexão com o banco (usando o Connection Pooler)
engine = create_engine(connection_string)

# Altera o nome da coluna "horainfracao" para "hora_infracao" e transfroma a hora para o tipo TIME
sql_commands =[
    text("""
    ALTER TABLE infracoes_brutas
    ADD COLUMN IF NOT EXISTS hora_infracao TIME;
    """),
    text("""
    UPDATE infracoes_brutas
    SET hora_infracao = horainfracao::TIME;
    """),
    text("""
    ALTER TABLE infracoes_brutas
    DROP COLUMN horainfracao;
    """)
]

try:
    # Garantir que a conexão seja fechada corretamente
    with engine.connect() as connection:
        for command in sql_commands:
            connection.execute(command)
            connection.commit()
    print("Instruções executadas com sucesso!")

except Exception as e:
    print(f"Ocorreu um erro ao executar o comando: {e}")
# Out:
# Instruções executadas com sucesso!

# %% [markdown]
# ## Tratamento da coluna dataimplantacao
# Realizamos a conversão da coluna dataimplantacao para o tipo DATE e a renomeamos para data_implantacao.

# %%
from sqlalchemy import create_engine, text

# Recria a conexão com o banco (usando o Connection Pooler)
engine = create_engine(connection_string)

# Altera o nome da coluna "dataimplantacao" para "data_implantacao", tira a hora e deixa somente a data (no formato DATE)
sql_commands =[
    text("""
    ALTER TABLE infracoes_brutas
    ADD COLUMN data_implantacao DATE;
    """),
    text("""
    UPDATE infracoes_brutas
    SET data_implantacao = CASE
    WHEN dataimplantacao LIKE '%/%' THEN CAST(TO_TIMESTAMP(dataimplantacao, 'DD/MM/YYYY HH24:MI') AS DATE)
    WHEN dataimplantacao LIKE '%-%' THEN TO_DATE(dataimplantacao, 'YYYY-MM-DD')
    ELSE NULL
    END;
    """),
    text("""
    ALTER TABLE infracoes_brutas
    DROP COLUMN dataimplantacao;
    """)
]

try:
    # Garantir que a conexão seja fechada corretamente
    with engine.connect() as connection:
        for command in sql_commands:
            connection.execute(command)
            connection.commit()
    print("Instruções executadas com sucesso!")

except Exception as e:
    print(f"Ocorreu um erro ao executar o comando: {e}")
# Out:
# Instruções executadas com sucesso!

# %% [markdown]
# ## Renomeando a coluna agenteequipamento
# Para seguir um padrão de nomenclatura, a coluna agenteequipamento foi renomeada para agente_equipamento.

# %%
from sqlalchemy import create_engine, text

# Recria a conexão com o banco (usando o Connection Pooler)
engine = create_engine(connection_string)

# Alterando o nome da coluna "agenteequipamento" para "agente_equipamento"
sql_commands =[
  text("""
  ALTER TABLE infracoes_brutas
  ADD COLUMN agente_equipamento TEXT;
  """),
  text("""
  UPDATE infracoes_brutas
  SET agente_equipamento = agenteequipamento;
  """),
  text("""
  ALTER TABLE infracoes_brutas
  DROP COLUMN agenteequipamento;
  """)
]

try:
    # Garantir que a conexão seja fechada corretamente
    with engine.connect() as connection:
        for command in sql_commands:
            connection.execute(command)
            connection.commit()
    print("Instruções executadas com sucesso!")

except Exception as e:
    print(f"Ocorreu um erro ao executar o comando: {e}")
# Out:
# Instruções executadas com sucesso!

# %% [markdown]
# ## Renomeando a coluna infracao
# Para seguir um padrão de nomenclatura, a coluna infracao foi renomeada para cod_infracao.

# %%
from sqlalchemy import create_engine, text

# Recria a conexão com o banco (usando o Connection Pooler)
engine = create_engine(connection_string)

# Alterando o nome da coluna "infracao" para "cod_infracao"
sql_commands = [
    # Renomeia a tabela atual para não perdermos os dados.
    text("""
    ALTER TABLE infracoes_brutas
    RENAME COLUMN infracao TO infracao_realocar;
    """),
    text("""
    ALTER TABLE infracoes_brutas
    ADD COLUMN cod_infracao BIGINT;
    """),
    text("""
    UPDATE infracoes_brutas
    SET cod_infracao = infracao_realocar;
    """),
    text("""
    ALTER TABLE infracoes_brutas
    DROP COLUMN infracao_realocar;
    """)
]

try:
    # Garantir que a conexão seja fechada corretamente
    with engine.connect() as connection:
        for command in sql_commands:
            connection.execute(command)
            connection.commit()
    print("Instruções executadas com sucesso!")

except Exception as e:
    print(f"Ocorreu um erro ao executar o comando: {e}")
# Out:
# Instruções executadas com sucesso!

# %% [markdown]
# ## Renomeando a coluna descricaoinfracao
# A coluna descricaoinfracao foi renomeada para descricao_infracao para manter a consistência.

# %%
from sqlalchemy import create_engine, text

# Recria a conexão com o banco (usando o Connection Pooler)
engine = create_engine(connection_string)

# Alterando o nome da coluna "descricaoinfracao" para "descricao_infracao"
sql_commands =[
    text("""
    ALTER TABLE infracoes_brutas
    ADD COLUMN descricao_infracao TEXT;
    """),
    text("""
    UPDATE infracoes_brutas
    SET descricao_infracao = descricaoinfracao;
    """),
    text("""
    ALTER TABLE infracoes_brutas
    DROP COLUMN descricaoinfracao;
    """)
]

try:
    # Garantir que a conexão seja fechada corretamente
    with engine.connect() as connection:
        for command in sql_commands:
            connection.execute(command)
            connection.commit()
    print("Instruções executadas com sucesso!")

except Exception as e:
    print(f"Ocorreu um erro ao executar o comando: {e}")
# Out:
# Instruções executadas com sucesso!

# %% [markdown]
# ## Renomeando a coluna localcometimento
# A coluna localcometimento foi renomeada para local_cometimento.

# %%
from sqlalchemy import create_engine, text

# Recria a conexão com o banco (usando o Connection Pooler)
engine = create_engine(connection_string)

# Altera o nome da coluna "localcometimento" para "local_cometimento"
sql_commands = [
    text("""
    ALTER TABLE infracoes_brutas
    ADD COLUMN local_cometimento TEXT;
    """),
    text("""
    UPDATE infracoes_brutas
    SET local_cometimento = CASE
        WHEN localcometimento IS NULL OR TRIM(localcometimento) = '' THEN 'Não informado'
        ELSE localcometimento
    END;
    """),
    text("""
    ALTER TABLE infracoes_brutas
    DROP COLUMN localcometimento;
    """)
]

try:
    # Garantir que a conexão seja fechada corretamente
    with engine.connect() as connection:
        for command in sql_commands:
            connection.execute(command)
            connection.commit()
    print("Instruções executadas com sucesso!")

except Exception as e:
    print(f"Ocorreu um erro ao executar o comando: {e}")
# Out:
# Instruções executadas com sucesso!

# %% [markdown]
# ## Tratamento da coluna amparolegal
# A coluna amparolegal foi dividida em duas novas colunas, artigo e subdivisao_artigo, para facilitar as consultas e análises

# %%
from sqlalchemy import create_engine, text

# Recria a conexão com o banco (usando o Connection Pooler)
engine = create_engine(connection_string)

# Substitue a coluna "amparolegal" por outras duas novas colunas, com "artigo" já sendo do tipo numérico.
sql_commands = [
    # Adiciona as novas colunas. Note que 'artigo' agora é INTEGER.
    text("""
    ALTER TABLE infracoes_brutas
    ADD COLUMN IF NOT EXISTS artigo TEXT,
    ADD COLUMN IF NOT EXISTS subdivisao_artigo TEXT;
    """),
    # Extrai os dados de 'amparolegal' para as novas colunas.
    # O número do artigo é extraído e convertido para INTEGER diretamente.
    text("""
    UPDATE infracoes_brutas
    SET
        artigo = CAST(substring(amparolegal from '\\d+') AS TEXT),
        subdivisao_artigo = trim(both ' ,' from regexp_replace(amparolegal, 'Art\\.\\s*\\d+', '', 'g'));
    """),
    # Padroniza os valores na coluna 'subdivisao_artigo'.
    # A flag 'gi' em regexp_replace significa 'global' e 'case-insensitive'.
    text("""
    UPDATE infracoes_brutas
    SET subdivisao_artigo =
        regexp_replace(
            regexp_replace(subdivisao_artigo, 'parágrafo único', '§ único', 'gi'),
            'inc(iso|\\.)', 'Inc.', 'gi'
        );
    """),
    # Preenche valores que ficaram vazios ou nulos com 'Não Informado'.
    text("""
    UPDATE infracoes_brutas
    SET artigo = 'Não informado'
    WHERE artigo IS NULL OR artigo = '';
    """),
    text("""
    UPDATE infracoes_brutas
    SET subdivisao_artigo = 'Não informado'
    WHERE subdivisao_artigo IS NULL OR subdivisao_artigo = '';
    """),
    # Remove a coluna original 'amparolegal'.
    text("""
    ALTER TABLE infracoes_brutas
    DROP COLUMN IF EXISTS amparolegal;
    """)
]

try:
    # Garantir que a conexão seja fechada corretamente
    with engine.connect() as connection:
        for command in sql_commands:
            connection.execute(command)
            connection.commit()
    print("Instruções executadas com sucesso!")

except Exception as e:
    print(f"Ocorreu um erro ao executar o comando: {e}")
# Out:
# Instruções executadas com sucesso!

# %% [markdown]
# ## Tratando Dados Ausentes em Colunas de Texto

# %%
from sqlalchemy import create_engine, text

# Recria a conexão com o banco (usando o Connection Pooler)
engine = create_engine(connection_string)

# Lista de colunas de texto a serem limpas
colunas_para_limpar = [
    'agente_equipamento',
    'descricao_infracao',
    'local_cometimento'
]

# Gera e executa um comando SQL para cada coluna
sql_commands = []
for coluna in colunas_para_limpar:
    comando = text(f"""
        UPDATE infracoes_brutas
        SET {coluna} = 'Não Informado'
        WHERE {coluna} IS NULL OR trim(both ' ' from {coluna}) = '';
    """)
    sql_commands.append(comando)

try:
    # Garantir que a conexão seja fechada corretamente
    with engine.connect() as connection:
        for command in sql_commands:
            connection.execute(command)
            connection.commit()
    print("SUCESSO! Valores nulos e vazios foram padronizados para 'Não Informado'.")

except Exception as e:
    print(f"Ocorreu um erro ao executar o comando: {e}")
# Out:
# SUCESSO! Valores nulos e vazios foram padronizados para 'Não Informado'.

# %% [markdown]
# ## Verificação Final dos Dados Transformados
# Após todas as transformações, executamos uma consulta final para visualizar o resultado e garantir que todas as modificações foram aplicadas corretamente

# %%
import pandas as pd
from sqlalchemy import text

print("Verificando o estado final da tabela 'infracoes_brutas'...")

try:
    # Garantir que a conexão seja fechada corretamente
    with engine.connect() as connection:
        # Query para selecionar as 10 infrações mais recentes e todas as suas colunas
        query_final = text("SELECT * FROM infracoes_brutas ORDER BY data_infracao DESC, hora_infracao DESC LIMIT 10")

        df_final = pd.read_sql_query(query_final, connection)

        print("SUCESSO! Amostra dos dados finais da tabela transformada:")

        # Exibe o DataFrame com o resultado final
        display(df_final)

except Exception as e:
    print(f"Ocorreu um erro ao tentar ler os dados finais do banco: {e}")
# Out:
# Verificando o estado final da tabela 'infracoes_brutas'...
# SUCESSO! Amostra dos dados finais da tabela transformada:
#   data_infracao hora_infracao data_implantacao agente_equipamento  \
# 0    2025-05-31      22:27:00       2025-06-04      Não Informado
# 1    2025-05-31      22:23:00       2025-06-04      Não Informado
# 2    2025-05-31      22:21:00       2025-06-04      Não Informado
# 3    2025-05-31      22:11:00       2025-06-04      Não Informado
# 4    2025-05-31      22:06:00       2025-06-04      Não Informado
# 5    2025-05-31      22:06:00       2025-06-04      Não Informado
# 6    2025-05-31      21:57:00       2025-06-03      Não Informado
# 7    2025-05-31      21:55:00       2025-06-03      Não Informado
# 8    2025-05-31      21:55:00       2025-06-04      Não Informado
# 9    2025-05-31      21:54:00       2025-06-03      Não Informado
#
#    cod_infracao                                 descricao_infracao  \
# 0          6599  Conduzir o veículo registrado que não esteja d...
# 1          6599  Conduzir o veículo registrado que não esteja d...
# 2          6599  Conduzir o veículo registrado que não esteja d...
# 3          6599  Conduzir o veículo registrado que não esteja d...
# 4          5010  Dirigir veículo sem possuir Carteira Nacional ...
# 5          5118  Permitir posse/condução do veículo a pessoa se...
# 6          7455  Transitar em velocidade superior à máxima perm...
# 7          7471  Transitar em velocidade superior à máxima perm...
# 8          5819  Transitar com veículo em canteiros centrais di...
# 9          7455  Transitar em velocidade superior à máxima perm...
#
#                                    local_cometimento artigo subdivisao_artigo
# 0     AVENIDA ANTONIO DE GOES, LADO OPOSTO AO N. 194    230            Inc. V
# 1   RUA AVENIDA ANTONIO DE GOES, EM FRENTE AO N. 194    230            Inc. V
# 2   RUA AVENIDA ANTONIO DE GOES, EM FRENTE AO N. 200    230            Inc. V
# 3     AVENIDA ANTONIO DE GOES, LADO OPOSTO AO N. 194    230            Inc. V
# 4       AVENIDA ANTONIO DE GOES, EM FRENTE AO N. 194    162            Inc. I
# 5       AVENIDA ANTONIO DE GOES, EM FRENTE AO N. 194    164      c/c , Inc. I
# 6  AV. BEBERIBE SANTA CRUZ F. C. , ENTRE O N. 409...    218            Inc. I
# 7        AV. GENERAL SAN MARTIN, N. 1864 - AV.RECIFE    218          Inc. III
# 8  AVENIDA JOAO DE BARROS, LADO OPOSTO AO N. 791S...    193     Não informado
# 9                  AV. CELSO FURTADO KM 1,5 - CENTRO    218            Inc. I

# %% [markdown]
# ## Consultas

# %% [markdown]
# 1. Mês com maior número de infrações

# %%
from sqlalchemy import create_engine, text

# Recria a conexão com o banco (usando o Connection Pooler)
engine = create_engine(connection_string)

# Conta o número total de infrações para cada mês
query_analise = """
SELECT
    TO_CHAR(data_infracao, 'YYYY-MM') AS mes_infracao,
    COUNT(*) AS total_de_infracoes
FROM
    infracoes_brutas
GROUP BY
    mes_infracao
ORDER BY
    total_de_infracoes DESC
LIMIT 1; -- Limita o resultado para mostrar apenas o primeiro da lista (o maior)
"""
try:
    with engine.connect() as connection:
        df_resultado = pd.read_sql_query(text(query_analise), connection)

    print("Ranking de meses com mais infrações:")
    print(df_resultado)

except Exception as e:
    print(f"Ocorreu um erro ao executar a consulta: {e}")
# Out:
# Ranking de meses com mais infrações:
#   mes_infracao  total_de_infracoes
# 0      2023-01               56669

# %% [markdown]
# 2. Horários com mais registros

# %%
from sqlalchemy import create_engine, text

# Recria a conexão com o banco (usando o Connection Pooler)
engine = create_engine(connection_string)

# Consulta para contar o número total de infrações para cada hora do dia
query_analise = """
SELECT
    EXTRACT(HOUR FROM hora_infracao) AS hora_do_dia,
    COUNT(*) AS total_de_infracoes
FROM
    infracoes_brutas
GROUP BY
    hora_do_dia
ORDER BY
    total_de_infracoes DESC
LIMIT 1; -- Limita o resultado para mostrar apenas o primeiro da lista (o maior)
"""

try:
    with engine.connect() as connection:
        df_resultado = pd.read_sql_query(text(query_analise), connection)

    print("Ranking de horários com mais infrações:")
    print(df_resultado)

except Exception as e:
    print(f"Ocorreu um erro ao executar a consulta: {e}")
# Out:
# Ranking de horários com mais infrações:
#    hora_do_dia  total_de_infracoes
# 0         15.0              112099

# %% [markdown]
# 3. Tipo de infração mais comum

# %%
from sqlalchemy import create_engine, text

engine = create_engine(connection_string)


# Consulta para contar as infrações, usando TRIM para limpar espaços em branco antes de agrupar
query_analise = """
SELECT
    TRIM(descricao_infracao) AS descricao_infracao,
    COUNT(*) AS total_de_ocorrencias
FROM
    infracoes_brutas
GROUP BY
    TRIM(descricao_infracao)
ORDER BY
    total_de_ocorrencias DESC
LIMIT 3;
"""



try:
    with engine.connect() as connection:
        df_resultado = pd.read_sql_query(text(query_analise), connection)

    print("Ranking dos 3 tipos de infração mais comuns:")

    df_resultado.index = range(1, len(df_resultado) + 1)

    display(df_resultado)

except Exception as e:
    print(f"Ocorreu um erro ao executar a consulta: {e}")
# Out:
# Ranking dos 3 tipos de infração mais comuns:
#                                   descricao_infracao  total_de_ocorrencias
# 1  Transitar em velocidade superior à máxima perm...                306426
# 2  Estacionar o veículo em desacordo com as condi...                143327
# 3  Transitar na faixa ou via exclusiva regulam.  ...                131447
